# %% [markdown]
# <a href="https://colab.research.google.com/github/Ariqq16/ML_2026/blob/main/JS02/JS02-Tugas_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
# Membaca dataset
df = pd.read_csv('sample_data/wbc.csv')

# %%
# 1. Menghapus kolom yang tidak digunakan
df = df.drop(columns=['id', 'Unnamed: 32'])

# %%
# 2. Encoding diagnosis
df['diagnosis'] = df['diagnosis'].map({
    'M': 1,
    'B': 0
})

# %%
# 3. Standardisasi data numerik
X = df.drop('diagnosis', axis=1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Mengubah kembali menjadi DataFrame
X_scaled = pd.DataFrame(
    X_scaled,
    columns=X.columns
)

# %%
# Menampilkan hasil
print(X_scaled.head())
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...
